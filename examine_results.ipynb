# %% [markdown]
# # Examine Results

# %%
import pandas as pd
import os

results_data = pd.read_parquet('all_results.parquet')
results_data
# Out:
#                             model                      simulation  \
# 0                      best_1_1.2                 open_loop_boxes
# 1                      best_1_1.2  closed_loop_nonreactive_agents
# 2                      best_1_1.2     closed_loop_reactive_agents
# 3                      best_1_2.0                 open_loop_boxes
# 4                      best_1_2.0  closed_loop_nonreactive_agents
# 5                      best_1_2.0     closed_loop_reactive_agents
# 6           best_1_1.2_no_seed_pe                 open_loop_boxes
# 7           best_1_1.2_no_seed_pe  closed_loop_nonreactive_agents
# 8           best_1_1.2_no_seed_pe     closed_loop_reactive_agents
# 9                      best_1_2.1                 open_loop_boxes
# 10                     best_1_2.1  closed_loop_nonreactive_agents
# 11                     best_1_2.1     closed_loop_reactive_agents
# 12                         best_1                 open_loop_boxes
# 13                         best_1  closed_loop_nonreactive_agents
# 14                         best_1     closed_loop_reactive_agents
# 15                  best_1_2.0_1M                 open_loop_boxes
# 16                  best_1_2.0_1M  closed_loop_nonreactive_agents
# 17                  best_1_2.0_1M     closed_loop_reactive_agents
# 18                      best_1_1M                 open_loop_boxes
# 19                      best_1_1M  closed_loop_nonreactive_agents
# 20                      best_1_1M     closed_loop_reactive_agents
# 21            best_1_1.2_rel_abla                 open_loop_boxes
# 22            best_1_1.2_rel_abla  closed_loop_nonreactive_agents
# 23            best_1_1.2_rel_abla     closed_loop_reactive_agents
# 24                     best_1_1.3                 open_loop_boxes
# 25                     best_1_1.3  closed_loop_nonreactive_agents
# 26                     best_1_1.3     closed_loop_reactive_agents
# 27                     best_1_3.0                 open_loop_boxes
# 28                     best_1_3.0  closed_loop_nonreactive_agents
# 29                     best_1_3.0     closed_loop_reactive_agents
# 30          ablation_loss_scaling                 open_loop_boxes
# 31          ablation_loss_scaling  closed_loop_nonreactive_agents
# 32          ablation_loss_scaling     closed_loop_reactive_agents
# 33            ablation_single_opt                 open_loop_boxes
# 34            ablation_single_opt  closed_loop_nonreactive_agents
# 35            ablation_single_opt     closed_loop_reactive_agents
# 36       ablation_FFNet_comp_traj                 open_loop_boxes
# 37       ablation_FFNet_comp_traj  closed_loop_nonreactive_agents
# 38       ablation_FFNet_comp_traj     closed_loop_reactive_agents
# 39       ablation_learnable_query                 open_loop_boxes
# 40       ablation_learnable_query  closed_loop_nonreactive_agents
# 41       ablation_learnable_query     closed_loop_reactive_agents
# 42           ablation_no_guidance                 open_loop_boxes
# 43           ablation_no_guidance  closed_loop_nonreactive_agents
# 44           ablation_no_guidance     closed_loop_reactive_agents
# 45   ablation_waypoints_number_10                 open_loop_boxes
# 46   ablation_waypoints_number_10  closed_loop_nonreactive_agents
# 47   ablation_waypoints_number_10     closed_loop_reactive_agents
# 48   ablation_waypoints_number_30                 open_loop_boxes
# 49   ablation_waypoints_number_30  closed_loop_nonreactive_agents
# 50   ablation_waypoints_number_30     closed_loop_reactive_agents
# 51   ablation_waypoints_number_40                 open_loop_boxes
# 52   ablation_waypoints_number_40  closed_loop_nonreactive_agents
# 53   ablation_waypoints_number_40     closed_loop_reactive_agents
# 54  ablation_single_TF_no_ego_vel                 open_loop_boxes
# 55  ablation_single_TF_no_ego_vel  closed_loop_nonreactive_agents
# 56  ablation_single_TF_no_ego_vel     closed_loop_reactive_agents
#
#        validation     scenario log_name scenario_type  num_scenarios  \
# 0   test14-random   best_1_1.2     None   final_score          261.0
# 1   test14-random  final_score     None   final_score          261.0
# 2   test14-random  final_score     None   final_score          261.0
# 3   test14-random  final_score     None   final_score          261.0
# 4   test14-random  final_score     None   final_score          261.0
# 5   test14-random  final_score     None   final_score          261.0
# 6   test14-random  final_score     None   final_score          261.0
# 7   test14-random  final_score     None   final_score          261.0
# 8   test14-random  final_score     None   final_score          261.0
# 9   test14-random  final_score     None   final_score          261.0
# 10  test14-random  final_score     None   final_score          261.0
# 11  test14-random  final_score     None   final_score          261.0
# 12    test14-hard  final_score     None   final_score          272.0
# 13    test14-hard  final_score     None   final_score          272.0
# 14    test14-hard  final_score     None   final_score          272.0
# 15  test14-random  final_score     None   final_score          261.0
# 16  test14-random  final_score     None   final_score          261.0
# 17  test14-random  final_score     None   final_score          261.0
# 18  test14-random  final_score     None   final_score          261.0
# 19  test14-random  final_score     None   final_score          261.0
# 20  test14-random  final_score     None   final_score          261.0
# 21  test14-random  final_score     None   final_score          261.0
# 22  test14-random  final_score     None   final_score          261.0
# 23  test14-random  final_score     None   final_score          261.0
# 24  test14-random  final_score     None   final_score          261.0
# 25  test14-random  final_score     None   final_score          261.0
# 26  test14-random  final_score     None   final_score          261.0
# 27  test14-random  final_score     None   final_score          261.0
# 28  test14-random  final_score     None   final_score          261.0
# 29  test14-random  final_score     None   final_score          261.0
# 30  test14-random  final_score     None   final_score          261.0
# 31  test14-random  final_score     None   final_score          261.0
# 32  test14-random  final_score     None   final_score          261.0
# 33  test14-random  final_score     None   final_score          261.0
# 34  test14-random  final_score     None   final_score          261.0
# 35  test14-random  final_score     None   final_score          261.0
# 36  test14-random  final_score     None   final_score          261.0
# 37  test14-random  final_score     None   final_score          261.0
# 38  test14-random  final_score     None   final_score          261.0
# 39  test14-random  final_score     None   final_score          261.0
# 40  test14-random  final_score     None   final_score          261.0
# 41  test14-random  final_score     None   final_score          261.0
# 42  test14-random  final_score     None   final_score          261.0
# 43  test14-random  final_score     None   final_score          261.0
# 44  test14-random  final_score     None   final_score          261.0
# 45  test14-random  final_score     None   final_score          261.0
# 46  test14-random  final_score     None   final_score          255.0
# 47  test14-random  final_score     None   final_score          252.0
# 48  test14-random  final_score     None   final_score          261.0
# 49  test14-random  final_score     None   final_score          261.0
# 50  test14-random  final_score     None   final_score          261.0
# 51  test14-random  final_score     None   final_score          261.0
# 52  test14-random  final_score     None   final_score          261.0
# 53  test14-random  final_score     None   final_score          261.0
# 54  test14-random  final_score     None   final_score          261.0
# 55  test14-random  final_score     None   final_score          261.0
# 56  test14-random  final_score     None   final_score          261.0
#
#         planner_name   aggregator_type  \
# 0   ImitationPlanner  weighted_average
# 1   ImitationPlanner  weighted_average
# 2   ImitationPlanner  weighted_average
# 3   ImitationPlanner  weighted_average
# 4   ImitationPlanner  weighted_average
# 5   ImitationPlanner  weighted_average
# 6   ImitationPlanner  weighted_average
# 7   ImitationPlanner  weighted_average
# 8   ImitationPlanner  weighted_average
# 9   ImitationPlanner  weighted_average
# 10  ImitationPlanner  weighted_average
# 11  ImitationPlanner  weighted_average
# 12  ImitationPlanner  weighted_average
# 13  ImitationPlanner  weighted_average
# 14  ImitationPlanner  weighted_average
# 15  ImitationPlanner  weighted_average
# 16  ImitationPlanner  weighted_average
# 17  ImitationPlanner  weighted_average
# 18  ImitationPlanner  weighted_average
# 19  ImitationPlanner  weighted_average
# 20  ImitationPlanner  weighted_average
# 21  ImitationPlanner  weighted_average
# 22  ImitationPlanner  weighted_average
# 23  ImitationPlanner  weighted_average
# 24  ImitationPlanner  weighted_average
# 25  ImitationPlanner  weighted_average
# 26  ImitationPlanner  weighted_average
# 27  ImitationPlanner  weighted_average
# 28  ImitationPlanner  weighted_average
# 29  ImitationPlanner  weighted_average
# 30  ImitationPlanner  weighted_average
# 31  ImitationPlanner  weighted_average
# 32  ImitationPlanner  weighted_average
# 33  ImitationPlanner  weighted_average
# 34  ImitationPlanner  weighted_average
# 35  ImitationPlanner  weighted_average
# 36  ImitationPlanner  weighted_average
# 37  ImitationPlanner  weighted_average
# 38  ImitationPlanner  weighted_average
# 39  ImitationPlanner  weighted_average
# 40  ImitationPlanner  weighted_average
# 41  ImitationPlanner  weighted_average
# 42  ImitationPlanner  weighted_average
# 43  ImitationPlanner  weighted_average
# 44  ImitationPlanner  weighted_average
# 45  ImitationPlanner  weighted_average
# 46  ImitationPlanner  weighted_average
# 47  ImitationPlanner  weighted_average
# 48  ImitationPlanner  weighted_average
# 49  ImitationPlanner  weighted_average
# 50  ImitationPlanner  weighted_average
# 51  ImitationPlanner  weighted_average
# 52  ImitationPlanner  weighted_average
# 53  ImitationPlanner  weighted_average
# 54  ImitationPlanner  weighted_average
# 55  ImitationPlanner  weighted_average
# 56  ImitationPlanner  weighted_average
#
#     planner_expert_average_heading_error_within_bound  ...  ego_lane_change  \
# 0                                            0.939399  ...             None
# 1                                                 NaN  ...             None
# 2                                                 NaN  ...             None
# 3                                            0.936166  ...             None
# 4                                                 NaN  ...             None
# 5                                                 NaN  ...             None
# 6                                            0.939587  ...             None
# 7                                                 NaN  ...             None
# 8                                                 NaN  ...             None
# 9                                            0.937172  ...             None
# 10                                                NaN  ...             None
# 11                                                NaN  ...             None
# 12                                           0.935957  ...             None
# 13                                                NaN  ...             None
# 14                                                NaN  ...             None
# 15                                           0.956908  ...             None
# 16                                                NaN  ...             None
# 17                                                NaN  ...             None
# 18                                           0.955878  ...             None
# 19                                                NaN  ...             None
# 20                                                NaN  ...             None
# 21                                           0.939116  ...             None
# 22                                                NaN  ...             None
# 23                                                NaN  ...             None
# 24                                           0.939208  ...             None
# 25                                                NaN  ...             None
# 26                                                NaN  ...             None
# 27                                           0.934173  ...             None
# 28                                                NaN  ...             None
# 29                                                NaN  ...             None
# 30                                           0.940832  ...             None
# 31                                                NaN  ...             None
# 32                                                NaN  ...             None
# 33                                           0.941479  ...             None
# 34                                                NaN  ...             None
# 35                                                NaN  ...             None
# 36                                           0.941675  ...             None
# 37                                                NaN  ...             None
# 38                                                NaN  ...             None
# 39                                           0.940015  ...             None
# 40                                                NaN  ...             None
# 41                                                NaN  ...             None
# 42                                           0.941558  ...             None
# 43                                                NaN  ...             None
# 44                                                NaN  ...             None
# 45                                           0.942734  ...             None
# 46                                                NaN  ...             None
# 47                                                NaN  ...             None
# 48                                           0.940286  ...             None
# 49                                                NaN  ...             None
# 50                                                NaN  ...             None
# 51                                           0.939508  ...             None
# 52                                                NaN  ...             None
# 53                                                NaN  ...             None
# 54                                           0.941208  ...             None
# 55                                                NaN  ...             None
# 56                                                NaN  ...             None
#
#     ego_lat_acceleration  ego_lon_acceleration  ego_lon_jerk  \
# 0                   None                  None          None
# 1                   None                  None          None
# 2                   None                  None          None
# 3                   None                  None          None
# 4                   None                  None          None
# 5                   None                  None          None
# 6                   None                  None          None
# 7                   None                  None          None
# 8                   None                  None          None
# 9                   None                  None          None
# 10                  None                  None          None
# 11                  None                  None          None
# 12                  None                  None          None
# 13                  None                  None          None
# 14                  None                  None          None
# 15                  None                  None          None
# 16                  None                  None          None
# 17                  None                  None          None
# 18                  None                  None          None
# 19                  None                  None          None
# 20                  None                  None          None
# 21                  None                  None          None
# 22                  None                  None          None
# 23                  None                  None          None
# 24                  None                  None          None
# 25                  None                  None          None
# 26                  None                  None          None
# 27                  None                  None          None
# 28                  None                  None          None
# 29                  None                  None          None
# 30                  None                  None          None
# 31                  None                  None          None
# 32                  None                  None          None
# 33                  None                  None          None
# 34                  None                  None          None
# 35                  None                  None          None
# 36                  None                  None          None
# 37                  None                  None          None
# 38                  None                  None          None
# 39                  None                  None          None
# 40                  None                  None          None
# 41                  None                  None          None
# 42                  None                  None          None
# 43                  None                  None          None
# 44                  None                  None          None
# 45                  None                  None          None
# 46                  None                  None          None
# 47                  None                  None          None
# 48                  None                  None          None
# 49                  None                  None          None
# 50                  None                  None          None
# 51                  None                  None          None
# 52                  None                  None          None
# 53                  None                  None          None
# 54                  None                  None          None
# 55                  None                  None          None
# 56                  None                  None          None
#
#     ego_progress_along_expert_route ego_yaw_acceleration  ego_yaw_rate  \
# 0                               NaN                 None          None
# 1                          0.891348                 None          None
# 2                          0.819820                 None          None
# 3                               NaN                 None          None
# 4                          0.895420                 None          None
# 5                          0.789550                 None          None
# 6                               NaN                 None          None
# 7                          0.900675                 None          None
# 8                          0.821443                 None          None
# 9                               NaN                 None          None
# 10                         0.897238                 None          None
# 11                         0.806929                 None          None
# 12                              NaN                 None          None
# 13                         0.875574                 None          None
# 14                         0.644404                 None          None
# 15                              NaN                 None          None
# 16                         0.940179                 None          None
# 17                         0.812599                 None          None
# 18                              NaN                 None          None
# 19                         0.943823                 None          None
# 20                         0.798906                 None          None
# 21                              NaN                 None          None
# 22                         0.892867                 None          None
# 23                         0.824084                 None          None
# 24                              NaN                 None          None
# 25                         0.901226                 None          None
# 26                         0.831651                 None          None
# 27                              NaN                 None          None
# 28                         0.898450                 None          None
# 29                         0.821836                 None          None
# 30                              NaN                 None          None
# 31                         0.896182                 None          None
# 32                         0.805175                 None          None
# 33                              NaN                 None          None
# 34                         0.896839                 None          None
# 35                         0.817964                 None          None
# 36                              NaN                 None          None
# 37                         0.875287                 None          None
# 38                         0.814940                 None          None
# 39                              NaN                 None          None
# 40                         0.899766                 None          None
# 41                         0.822327                 None          None
# 42                              NaN                 None          None
# 43                         0.911139                 None          None
# 44                         0.832458                 None          None
# 45                              NaN                 None          None
# 46                         0.602958                 None          None
# 47                         0.635962                 None          None
# 48                              NaN                 None          None
# 49                         0.896996                 None          None
# 50                         0.806780                 None          None
# 51                              NaN                 None          None
# 52                         0.897384                 None          None
# 53                         0.813063                 None          None
# 54                              NaN                 None          None
# 55                         0.882608                 None          None
# 56                         0.803432                 None          None
#
#     no_ego_at_fault_collisions  speed_limit_compliance  \
# 0                          NaN                     NaN
# 1                     0.904215                0.971554
# 2                     0.948276                0.976302
# 3                          NaN                     NaN
# 4                     0.946360                0.971685
# 5                     0.963602                0.980458
# 6                          NaN                     NaN
# 7                     0.927203                0.970666
# 8                     0.944444                0.976394
# 9                          NaN                     NaN
# 10                    0.942529                0.971671
# 11                    0.942529                0.980240
# 12                         NaN                     NaN
# 13                    0.852941                0.968730
# 14                    0.904412                0.984580
# 15                         NaN                     NaN
# 16                    0.923372                0.959264
# 17                    0.940613                0.977865
# 18                         NaN                     NaN
# 19                    0.938697                0.961609
# 20                    0.934866                0.978626
# 21                         NaN                     NaN
# 22                    0.925287                0.972833
# 23                    0.936782                0.979994
# 24                         NaN                     NaN
# 25                    0.908046                0.971399
# 26                    0.946360                0.975133
# 27                         NaN                     NaN
# 28                    0.925287                0.964791
# 29                    0.957854                0.972339
# 30                         NaN                     NaN
# 31                    0.931034                0.972465
# 32                    0.946360                0.977051
# 33                         NaN                     NaN
# 34                    0.929119                0.972376
# 35                    0.961686                0.976831
# 36                         NaN                     NaN
# 37                    0.877395                0.969764
# 38                    0.932950                0.977322
# 39                         NaN                     NaN
# 40                    0.931034                0.968608
# 41                    0.948276                0.976009
# 42                         NaN                     NaN
# 43                    0.913793                0.968630
# 44                    0.936782                0.974201
# 45                         NaN                     NaN
# 46                    0.558824                0.536693
# 47                    0.432540                0.442915
# 48                         NaN                     NaN
# 49                    0.938697                0.970372
# 50                    0.954023                0.978343
# 51                         NaN                     NaN
# 52                    0.940613                0.973064
# 53                    0.952107                0.979277
# 54                         NaN                     NaN
# 55                    0.934866                0.972871
# 56                    0.944444                0.979556
#
#     time_to_collision_within_bound
# 0                              NaN
# 1                         0.881226
# 2                         0.915709
# 3                              NaN
# 4                         0.931034
# 5                         0.931034
# 6                              NaN
# 7                         0.873563
# 8                         0.904215
# 9                              NaN
# 10                        0.915709
# 11                        0.904215
# 12                             NaN
# 13                        0.764706
# 14                        0.838235
# 15                             NaN
# 16                        0.888889
# 17                        0.885057
# 18                             NaN
# 19                        0.900383
# 20                        0.904215
# 21                             NaN
# 22                        0.877395
# 23                        0.900383
# 24                             NaN
# 25                        0.865900
# 26                        0.900383
# 27                             NaN
# 28                        0.888889
# 29                        0.908046
# 30                             NaN
# 31                        0.885057
# 32                        0.927203
# 33                             NaN
# 34                        0.881226
# 35                        0.915709
# 36                             NaN
# 37                        0.858238
# 38                        0.900383
# 39                             NaN
# 40                        0.915709
# 41                        0.911877
# 42                             NaN
# 43                        0.873563
# 44                        0.919540
# 45                             NaN
# 46                        0.490196
# 47                        0.369048
# 48                             NaN
# 49                        0.908046
# 50                        0.908046
# 51                             NaN
# 52                        0.896552
# 53                        0.919540
# 54                             NaN
# 55                        0.896552
# 56                        0.915709
#
# [57 rows x 31 columns]

# %%
pd.concat([results_data[:3],results_data[-3:]])
# Out:
#                            model                      simulation  \
# 0                     best_1_1.2                 open_loop_boxes
# 1                     best_1_1.2  closed_loop_nonreactive_agents
# 2                     best_1_1.2     closed_loop_reactive_agents
# 45  ablation_waypoints_number_10                 open_loop_boxes
# 46  ablation_waypoints_number_10  closed_loop_nonreactive_agents
# 47  ablation_waypoints_number_10     closed_loop_reactive_agents
#
#        validation     scenario log_name scenario_type  num_scenarios  \
# 0   test14-random   best_1_1.2     None   final_score          261.0
# 1   test14-random  final_score     None   final_score          261.0
# 2   test14-random  final_score     None   final_score          261.0
# 45  test14-random  final_score     None   final_score          261.0
# 46  test14-random  final_score     None   final_score          255.0
# 47  test14-random  final_score     None   final_score          252.0
#
#         planner_name   aggregator_type  \
# 0   ImitationPlanner  weighted_average
# 1   ImitationPlanner  weighted_average
# 2   ImitationPlanner  weighted_average
# 45  ImitationPlanner  weighted_average
# 46  ImitationPlanner  weighted_average
# 47  ImitationPlanner  weighted_average
#
#     planner_expert_average_heading_error_within_bound  ...  ego_lane_change  \
# 0                                            0.939399  ...             None
# 1                                                 NaN  ...             None
# 2                                                 NaN  ...             None
# 45                                           0.942734  ...             None
# 46                                                NaN  ...             None
# 47                                                NaN  ...             None
#
#     ego_lat_acceleration  ego_lon_acceleration  ego_lon_jerk  \
# 0                   None                  None          None
# 1                   None                  None          None
# 2                   None                  None          None
# 45                  None                  None          None
# 46                  None                  None          None
# 47                  None                  None          None
#
#     ego_progress_along_expert_route ego_yaw_acceleration  ego_yaw_rate  \
# 0                               NaN                 None          None
# 1                          0.891348                 None          None
# 2                          0.819820                 None          None
# 45                              NaN                 None          None
# 46                         0.602958                 None          None
# 47                         0.635962                 None          None
#
#     no_ego_at_fault_collisions  speed_limit_compliance  \
# 0                          NaN                     NaN
# 1                     0.904215                0.971554
# 2                     0.948276                0.976302
# 45                         NaN                     NaN
# 46                    0.558824                0.536693
# 47                    0.432540                0.442915
#
#     time_to_collision_within_bound
# 0                              NaN
# 1                         0.881226
# 2                         0.915709
# 45                             NaN
# 46                        0.490196
# 47                        0.369048
#
# [6 rows x 31 columns]

# %% [markdown]
# ## Sort and modify results log

# %%
def add_results_to_record(model_name, sim_type, val_set_name, simulation_folder_path, log_parquet_path = './all_results.parquet'):
    sheet_name = model_name + '--' + sim_type + '--' + val_set_name
    input_parquet_path = simulation_folder_path + sim_type + '/' + val_set_name + '/aggregator_metric/'
    # read the only file in the directory
    input_parquet_path = input_parquet_path + os.listdir(input_parquet_path)[0]

    # copy the input parquet file to the results folder
    import shutil
    shutil.copy(input_parquet_path, os.path.expanduser('~/Documents/results/' + sheet_name + '.parquet'))
    # Read the input parquet file
    new_data = pd.read_parquet(input_parquet_path)
    
    # Check if the log parquet file exists
    if os.path.exists(log_parquet_path):
        # Read the existing log parquet file
        log_data = pd.read_parquet(log_parquet_path)
    else:
        raise FileNotFoundError('The log parquet file does not exist.')
    
    score_row = new_data.loc[new_data['scenario'] == 'final_score']
    score_row.insert(0, 'model', model_name)
    score_row.insert(1, 'simulation', sim_type)
    score_row.insert(2, 'validation', val_set_name)    
    
    log_data = pd.concat([log_data, score_row], ignore_index=True)
    # Write the log parquet file
    # log_data.to_parquet(log_parquet_path)
    return log_data

# %%
# Example usage
model_name = 'ablation_single_TF_with_ego_vel'
val_set_name = 'test14-random' # 'test14-random', 'test14-hard', 'val14'
for sim_type in ['open_loop_boxes', 'closed_loop_nonreactive_agents', 'closed_loop_reactive_agents']:
    # input_parquet_path = '/home/jiale/Documents/exp/exp/simulation/' + sim_type + '/' + val_set_name + '/aggregator_metric/'
    simulation_folder_path = '/home/jiale/Documents/exp/exp/simulation/'
    log_parquet_path = './all_results.parquet'
    log_data = add_results_to_record(model_name, sim_type, val_set_name, simulation_folder_path)
    log_data.to_parquet(log_parquet_path)

# %% [markdown]
# ## Others

# %%
# modify the specified cell
# sim_type_list = ['open_loop_boxes', 'closed_loop_nonreactive_agents', 'closed_loop_reactive_agents']
# for i in range(6):
#     results_data.at[i, 'simulation'] = sim_type_list[i % 3]
# for i in range(6,9):
#     results_data.at[i, 'model'] = "best_1_1.2_no_seed_pe"
results_data = results_data[:-3]
results_data
# Out:
#                     model                      simulation     validation  \
# 0              best_1_1.2                 open_loop_boxes  test14-random
# 1              best_1_1.2  closed_loop_nonreactive_agents  test14-random
# 2              best_1_1.2     closed_loop_reactive_agents  test14-random
# 3              best_1_2.0                 open_loop_boxes  test14-random
# 4              best_1_2.0  closed_loop_nonreactive_agents  test14-random
# 5              best_1_2.0     closed_loop_reactive_agents  test14-random
# 6   best_1_1.2_no_seed_pe                 open_loop_boxes  test14-random
# 7   best_1_1.2_no_seed_pe  closed_loop_nonreactive_agents  test14-random
# 8   best_1_1.2_no_seed_pe     closed_loop_reactive_agents  test14-random
# 9              best_1_2.1                 open_loop_boxes  test14-random
# 10             best_1_2.1  closed_loop_nonreactive_agents  test14-random
# 11             best_1_2.1     closed_loop_reactive_agents  test14-random
# 12                 best_1                 open_loop_boxes    test14-hard
# 13                 best_1  closed_loop_nonreactive_agents    test14-hard
# 14                 best_1     closed_loop_reactive_agents    test14-hard
# 15          best_1_2.0_1M                 open_loop_boxes  test14-random
# 16          best_1_2.0_1M  closed_loop_nonreactive_agents  test14-random
# 17          best_1_2.0_1M     closed_loop_reactive_agents  test14-random
# 18              best_1_1M                 open_loop_boxes  test14-random
# 19              best_1_1M  closed_loop_nonreactive_agents  test14-random
# 20              best_1_1M     closed_loop_reactive_agents  test14-random
# 21    best_1_1.2_rel_abla                 open_loop_boxes  test14-random
# 22    best_1_1.2_rel_abla  closed_loop_nonreactive_agents  test14-random
# 23    best_1_1.2_rel_abla     closed_loop_reactive_agents  test14-random
#
#        scenario log_name scenario_type  num_scenarios      planner_name  \
# 0    best_1_1.2     None   final_score          261.0  ImitationPlanner
# 1   final_score     None   final_score          261.0  ImitationPlanner
# 2   final_score     None   final_score          261.0  ImitationPlanner
# 3   final_score     None   final_score          261.0  ImitationPlanner
# 4   final_score     None   final_score          261.0  ImitationPlanner
# 5   final_score     None   final_score          261.0  ImitationPlanner
# 6   final_score     None   final_score          261.0  ImitationPlanner
# 7   final_score     None   final_score          261.0  ImitationPlanner
# 8   final_score     None   final_score          261.0  ImitationPlanner
# 9   final_score     None   final_score          261.0  ImitationPlanner
# 10  final_score     None   final_score          261.0  ImitationPlanner
# 11  final_score     None   final_score          261.0  ImitationPlanner
# 12  final_score     None   final_score          272.0  ImitationPlanner
# 13  final_score     None   final_score          272.0  ImitationPlanner
# 14  final_score     None   final_score          272.0  ImitationPlanner
# 15  final_score     None   final_score          261.0  ImitationPlanner
# 16  final_score     None   final_score          261.0  ImitationPlanner
# 17  final_score     None   final_score          261.0  ImitationPlanner
# 18  final_score     None   final_score          261.0  ImitationPlanner
# 19  final_score     None   final_score          261.0  ImitationPlanner
# 20  final_score     None   final_score          261.0  ImitationPlanner
# 21  final_score     None   final_score          261.0  ImitationPlanner
# 22  final_score     None   final_score          261.0  ImitationPlanner
# 23  final_score     None   final_score          261.0  ImitationPlanner
#
#      aggregator_type  planner_expert_average_heading_error_within_bound  ...  \
# 0   weighted_average                                           0.939399  ...
# 1   weighted_average                                                NaN  ...
# 2   weighted_average                                                NaN  ...
# 3   weighted_average                                           0.936166  ...
# 4   weighted_average                                                NaN  ...
# 5   weighted_average                                                NaN  ...
# 6   weighted_average                                           0.939587  ...
# 7   weighted_average                                                NaN  ...
# 8   weighted_average                                                NaN  ...
# 9   weighted_average                                           0.937172  ...
# 10  weighted_average                                                NaN  ...
# 11  weighted_average                                                NaN  ...
# 12  weighted_average                                           0.935957  ...
# 13  weighted_average                                                NaN  ...
# 14  weighted_average                                                NaN  ...
# 15  weighted_average                                           0.956908  ...
# 16  weighted_average                                                NaN  ...
# 17  weighted_average                                                NaN  ...
# 18  weighted_average                                           0.955878  ...
# 19  weighted_average                                                NaN  ...
# 20  weighted_average                                                NaN  ...
# 21  weighted_average                                           0.939116  ...
# 22  weighted_average                                                NaN  ...
# 23  weighted_average                                                NaN  ...
#
#     ego_lane_change  ego_lat_acceleration  ego_lon_acceleration  ego_lon_jerk  \
# 0              None                  None                  None          None
# 1              None                  None                  None          None
# 2              None                  None                  None          None
# 3              None                  None                  None          None
# 4              None                  None                  None          None
# 5              None                  None                  None          None
# 6              None                  None                  None          None
# 7              None                  None                  None          None
# 8              None                  None                  None          None
# 9              None                  None                  None          None
# 10             None                  None                  None          None
# 11             None                  None                  None          None
# 12             None                  None                  None          None
# 13             None                  None                  None          None
# 14             None                  None                  None          None
# 15             None                  None                  None          None
# 16             None                  None                  None          None
# 17             None                  None                  None          None
# 18             None                  None                  None          None
# 19             None                  None                  None          None
# 20             None                  None                  None          None
# 21             None                  None                  None          None
# 22             None                  None                  None          None
# 23             None                  None                  None          None
#
#     ego_progress_along_expert_route ego_yaw_acceleration  ego_yaw_rate  \
# 0                               NaN                 None          None
# 1                          0.891348                 None          None
# 2                          0.819820                 None          None
# 3                               NaN                 None          None
# 4                          0.895420                 None          None
# 5                          0.789550                 None          None
# 6                               NaN                 None          None
# 7                          0.900675                 None          None
# 8                          0.821443                 None          None
# 9                               NaN                 None          None
# 10                         0.897238                 None          None
# 11                         0.806929                 None          None
# 12                              NaN                 None          None
# 13                         0.875574                 None          None
# 14                         0.644404                 None          None
# 15                              NaN                 None          None
# 16                         0.940179                 None          None
# 17                         0.812599                 None          None
# 18                              NaN                 None          None
# 19                         0.943823                 None          None
# 20                         0.798906                 None          None
# 21                              NaN                 None          None
# 22                         0.892867                 None          None
# 23                         0.824084                 None          None
#
#     no_ego_at_fault_collisions  speed_limit_compliance  \
# 0                          NaN                     NaN
# 1                     0.904215                0.971554
# 2                     0.948276                0.976302
# 3                          NaN                     NaN
# 4                     0.946360                0.971685
# 5                     0.963602                0.980458
# 6                          NaN                     NaN
# 7                     0.927203                0.970666
# 8                     0.944444                0.976394
# 9                          NaN                     NaN
# 10                    0.942529                0.971671
# 11                    0.942529                0.980240
# 12                         NaN                     NaN
# 13                    0.852941                0.968730
# 14                    0.904412                0.984580
# 15                         NaN                     NaN
# 16                    0.923372                0.959264
# 17                    0.940613                0.977865
# 18                         NaN                     NaN
# 19                    0.938697                0.961609
# 20                    0.934866                0.978626
# 21                         NaN                     NaN
# 22                    0.925287                0.972833
# 23                    0.936782                0.979994
#
#     time_to_collision_within_bound
# 0                              NaN
# 1                         0.881226
# 2                         0.915709
# 3                              NaN
# 4                         0.931034
# 5                         0.931034
# 6                              NaN
# 7                         0.873563
# 8                         0.904215
# 9                              NaN
# 10                        0.915709
# 11                        0.904215
# 12                             NaN
# 13                        0.764706
# 14                        0.838235
# 15                             NaN
# 16                        0.888889
# 17                        0.885057
# 18                             NaN
# 19                        0.900383
# 20                        0.904215
# 21                             NaN
# 22                        0.877395
# 23                        0.900383
#
# [24 rows x 31 columns]

# %%
results_data.to_parquet('all_results.parquet')
results_data
# Out:
#                     model                      simulation     validation  \
# 0              best_1_1.2                 open_loop_boxes  test14-random
# 1              best_1_1.2  closed_loop_nonreactive_agents  test14-random
# 2              best_1_1.2     closed_loop_reactive_agents  test14-random
# 3              best_1_2.0                 open_loop_boxes  test14-random
# 4              best_1_2.0  closed_loop_nonreactive_agents  test14-random
# 5              best_1_2.0     closed_loop_reactive_agents  test14-random
# 6   best_1_1.2_no_seed_pe                 open_loop_boxes  test14-random
# 7   best_1_1.2_no_seed_pe  closed_loop_nonreactive_agents  test14-random
# 8   best_1_1.2_no_seed_pe     closed_loop_reactive_agents  test14-random
# 9              best_1_2.1                 open_loop_boxes  test14-random
# 10             best_1_2.1  closed_loop_nonreactive_agents  test14-random
# 11             best_1_2.1     closed_loop_reactive_agents  test14-random
# 12                 best_1                 open_loop_boxes    test14-hard
# 13                 best_1  closed_loop_nonreactive_agents    test14-hard
# 14                 best_1     closed_loop_reactive_agents    test14-hard
# 15          best_1_2.0_1M                 open_loop_boxes  test14-random
# 16          best_1_2.0_1M  closed_loop_nonreactive_agents  test14-random
# 17          best_1_2.0_1M     closed_loop_reactive_agents  test14-random
#
#        scenario log_name scenario_type  num_scenarios      planner_name  \
# 0    best_1_1.2     None   final_score          261.0  ImitationPlanner
# 1   final_score     None   final_score          261.0  ImitationPlanner
# 2   final_score     None   final_score          261.0  ImitationPlanner
# 3   final_score     None   final_score          261.0  ImitationPlanner
# 4   final_score     None   final_score          261.0  ImitationPlanner
# 5   final_score     None   final_score          261.0  ImitationPlanner
# 6   final_score     None   final_score          261.0  ImitationPlanner
# 7   final_score     None   final_score          261.0  ImitationPlanner
# 8   final_score     None   final_score          261.0  ImitationPlanner
# 9   final_score     None   final_score          261.0  ImitationPlanner
# 10  final_score     None   final_score          261.0  ImitationPlanner
# 11  final_score     None   final_score          261.0  ImitationPlanner
# 12  final_score     None   final_score          272.0  ImitationPlanner
# 13  final_score     None   final_score          272.0  ImitationPlanner
# 14  final_score     None   final_score          272.0  ImitationPlanner
# 15  final_score     None   final_score          261.0  ImitationPlanner
# 16  final_score     None   final_score          261.0  ImitationPlanner
# 17  final_score     None   final_score          261.0  ImitationPlanner
#
#      aggregator_type  planner_expert_average_heading_error_within_bound  ...  \
# 0   weighted_average                                           0.939399  ...
# 1   weighted_average                                                NaN  ...
# 2   weighted_average                                                NaN  ...
# 3   weighted_average                                           0.936166  ...
# 4   weighted_average                                                NaN  ...
# 5   weighted_average                                                NaN  ...
# 6   weighted_average                                           0.939587  ...
# 7   weighted_average                                                NaN  ...
# 8   weighted_average                                                NaN  ...
# 9   weighted_average                                           0.937172  ...
# 10  weighted_average                                                NaN  ...
# 11  weighted_average                                                NaN  ...
# 12  weighted_average                                           0.935957  ...
# 13  weighted_average                                                NaN  ...
# 14  weighted_average                                                NaN  ...
# 15  weighted_average                                           0.956908  ...
# 16  weighted_average                                                NaN  ...
# 17  weighted_average                                                NaN  ...
#
#     ego_lane_change  ego_lat_acceleration  ego_lon_acceleration  ego_lon_jerk  \
# 0              None                  None                  None          None
# 1              None                  None                  None          None
# 2              None                  None                  None          None
# 3              None                  None                  None          None
# 4              None                  None                  None          None
# 5              None                  None                  None          None
# 6              None                  None                  None          None
# 7              None                  None                  None          None
# 8              None                  None                  None          None
# 9              None                  None                  None          None
# 10             None                  None                  None          None
# 11             None                  None                  None          None
# 12             None                  None                  None          None
# 13             None                  None                  None          None
# 14             None                  None                  None          None
# 15             None                  None                  None          None
# 16             None                  None                  None          None
# 17             None                  None                  None          None
#
#     ego_progress_along_expert_route ego_yaw_acceleration  ego_yaw_rate  \
# 0                               NaN                 None          None
# 1                          0.891348                 None          None
# 2                          0.819820                 None          None
# 3                               NaN                 None          None
# 4                          0.895420                 None          None
# 5                          0.789550                 None          None
# 6                               NaN                 None          None
# 7                          0.900675                 None          None
# 8                          0.821443                 None          None
# 9                               NaN                 None          None
# 10                         0.897238                 None          None
# 11                         0.806929                 None          None
# 12                              NaN                 None          None
# 13                         0.875574                 None          None
# 14                         0.644404                 None          None
# 15                              NaN                 None          None
# 16                         0.940179                 None          None
# 17                         0.812599                 None          None
#
#     no_ego_at_fault_collisions  speed_limit_compliance  \
# 0                          NaN                     NaN
# 1                     0.904215                0.971554
# 2                     0.948276                0.976302
# 3                          NaN                     NaN
# 4                     0.946360                0.971685
# 5                     0.963602                0.980458
# 6                          NaN                     NaN
# 7                     0.927203                0.970666
# 8                     0.944444                0.976394
# 9                          NaN                     NaN
# 10                    0.942529                0.971671
# 11                    0.942529                0.980240
# 12                         NaN                     NaN
# 13                    0.852941                0.968730
# 14                    0.904412                0.984580
# 15                         NaN                     NaN
# 16                    0.923372                0.959264
# 17                    0.940613                0.977865
#
#     time_to_collision_within_bound
# 0                              NaN
# 1                         0.881226
# 2                         0.915709
# 3                              NaN
# 4                         0.931034
# 5                         0.931034
# 6                              NaN
# 7                         0.873563
# 8                         0.904215
# 9                              NaN
# 10                        0.915709
# 11                        0.904215
# 12                             NaN
# 13                        0.764706
# 14                        0.838235
# 15                             NaN
# 16                        0.888889
# 17                        0.885057
#
# [18 rows x 31 columns]

# %%
# modify the scenario name to be more readable
results_data.at[0, 'scenario'] = 'best_1_1.2'
# add three new columns with the name of the model, type of simulation and the type of validation set
results_data.insert(0, 'model', 'DE')
results_data.insert(1, 'simulation', 'validation')
results_data.insert(2, 'validation', 'test')

# # save the modified data
results_data.to_parquet('all_results.parquet')
results_data
# Out:
#   model  simulation validation     scenario log_name scenario_type  \
# 0    DE  validation       test   best_1_1.2     None   final_score
# 1    DE  validation       test  final_score     None   final_score
# 2    DE  validation       test  final_score     None   final_score
# 3    DE  validation       test  final_score     None   final_score
# 4    DE  validation       test  final_score     None   final_score
# 5    DE  validation       test  final_score     None   final_score
#
#    num_scenarios      planner_name   aggregator_type  \
# 0          261.0  ImitationPlanner  weighted_average
# 1          261.0  ImitationPlanner  weighted_average
# 2          261.0  ImitationPlanner  weighted_average
# 3          261.0  ImitationPlanner  weighted_average
# 4          261.0  ImitationPlanner  weighted_average
# 5          261.0  ImitationPlanner  weighted_average
#
#    planner_expert_average_heading_error_within_bound  ...  ego_lane_change  \
# 0                                           0.939399  ...             None
# 1                                                NaN  ...             None
# 2                                                NaN  ...             None
# 3                                           0.936166  ...             None
# 4                                                NaN  ...             None
# 5                                                NaN  ...             None
#
#    ego_lat_acceleration  ego_lon_acceleration  ego_lon_jerk  \
# 0                  None                  None          None
# 1                  None                  None          None
# 2                  None                  None          None
# 3                  None                  None          None
# 4                  None                  None          None
# 5                  None                  None          None
#
#    ego_progress_along_expert_route ego_yaw_acceleration  ego_yaw_rate  \
# 0                              NaN                 None          None
# 1                         0.891348                 None          None
# 2                         0.819820                 None          None
# 3                              NaN                 None          None
# 4                         0.895420                 None          None
# 5                         0.789550                 None          None
#
#    no_ego_at_fault_collisions  speed_limit_compliance  \
# 0                         NaN                     NaN
# 1                    0.904215                0.971554
# 2                    0.948276                0.976302
# 3                         NaN                     NaN
# 4                    0.946360                0.971685
# 5                    0.963602                0.980458
#
#    time_to_collision_within_bound
# 0                             NaN
# 1                        0.881226
# 2                        0.915709
# 3                             NaN
# 4                        0.931034
# 5                        0.931034
#
# [6 rows x 31 columns]
